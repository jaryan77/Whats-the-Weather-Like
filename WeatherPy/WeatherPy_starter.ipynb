# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Set up url and search url by calling into OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build partial query URL
search_url = f"{url}&units={units}&appid={weather_api_key}"

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
latitudes = []
longitudes = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        latitudes.append(lat_lng[0])
        longitudes.append(lat_lng[1])

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %%
# dict = {
#     "City": cities,
#     "Latitude": latitudes,
#     "Longitude": longitudes
# }

# city_df = pd.DataFrame(dict)
# city_df.head()

# %%
#Perform API calls
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

#for index, row in city_df.iterrows():
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    
    city_url = search_url + "&q=" + city
    
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    record_count += 1
    
    
    try:
        response = requests.get(city_url).json()
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        max_temp = response["main"]["temp_max"]
        city_humid = response["main"]["humidity"]
        city_cloud = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        country = response["sys"]["country"]
        weather_date = response["dt"]
        
        city_data.append({"City": city,
                        "Lat": city_lat,
                         "Lng" : city_lng,
                         "Max Temp": max_temp,
                         "Humidity": city_humid,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Country": country,
                         "Date": weather_date})

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# print("{city}, {lat_lng}, {temp}")

# city_temp = {
#     "City": cities,
#     "Latitude": latitudes,
#     "Longitude": longitudes,
#     "Temperature": temps
# }

# weather_df = pd.DataFrame(city_df)
# weather_df.head()
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nantucket
# Processing Record 2 of Set 1 | leh
# Processing Record 3 of Set 1 | waddan
# Processing Record 4 of Set 1 | benito juarez
# Processing Record 5 of Set 1 | nioro
# Processing Record 6 of Set 1 | hofn
# Processing Record 7 of Set 1 | fukue
# Processing Record 8 of Set 1 | vetluzhskiy
# Processing Record 9 of Set 1 | faanui
# Processing Record 10 of Set 1 | bathsheba
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | vardo
# Processing Record 13 of Set 1 | mizpe ramon
# City not found. Skipping...
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | lamar
# Processing Record 18 of Set 1 | jiuquan
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | kenai
# Processing Record 22 of Set 1 | fare
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | ksenyevka
# City not found. Skipping...
# Processing Record 25 of Set 1 | marihatag
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | odweyne
# Processing Record 31 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | san cristobal
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | tabuk
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | comodoro rivadavia
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | shache
# Processing Record 42 of Set 1 | coihaique
# Processing Record 43 of Set 1 | sambava
# Processing Record 44 of Set 1 | balkanabat
# Processing Record 45 of Set 1 | adrar
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | kwidzyn
# Processing Record 48 of Set 1 | linjiang
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | chapais
# Processing Record 0 of Set 2 | punta arenas
# Processing Record 1 of Set 2 | paita
# Processing Record 2 of Set 2 | povenets
# Processing Record 3 of Set 2 | mata
# Processing Record 4 of Set 2 | medvezhyegorsk
# Processing Record 5 of Set 2 | guajara
# Processing Record 6 of Set 2 | paamiut
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | nome
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | muros
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | maragogi
# Processing Record 15 of Set 2 | sao filipe
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | beloha
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | keningau
# Processing Record 21 of Set 2 | lubao
# Processing Record 22 of Set 2 | hambantota
# Processing Record 23 of Set 2 | chokurdakh
# Processing Record 24 of Set 2 | cayenne
# Processing Record 25 of Set 2 | ukholovo
# Processing Record 26 of Set 2 | buin
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | laguna
# Processing Record 29 of Set 2 | yakshur-bodya
# City not found. Skipping...
# Processing Record 30 of Set 2 | ouargaye
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | amazar
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | galveston
# Processing Record 36 of Set 2 | komsomolskiy
# Processing Record 37 of Set 2 | tiksi
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | ponta do sol
# Processing Record 41 of Set 2 | atar
# Processing Record 42 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 2 | jiancheng
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | nouadhibou
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | naze
# Processing Record 48 of Set 2 | aguimes
# Processing Record 49 of Set 2 | castro
# Processing Record 0 of Set 3 | praia da vitoria
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | provideniya
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | elko
# Processing Record 6 of Set 3 | kidal
# Processing Record 7 of Set 3 | norman wells
# Processing Record 8 of Set 3 | pisco
# Processing Record 9 of Set 3 | lasa
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | predivinsk
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | belmonte
# Processing Record 14 of Set 3 | biloela
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | myslenice
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | saint-francois
# Processing Record 19 of Set 3 | half moon bay
# Processing Record 20 of Set 3 | kuytun
# Processing Record 21 of Set 3 | guerrero negro
# Processing Record 22 of Set 3 | cam pha
# City not found. Skipping...
# Processing Record 23 of Set 3 | vao
# Processing Record 24 of Set 3 | kampong cham
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | rawson
# Processing Record 27 of Set 3 | tabou
# Processing Record 28 of Set 3 | geraldton
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | huilong
# Processing Record 31 of Set 3 | deputatskiy
# Processing Record 32 of Set 3 | eyl
# Processing Record 33 of Set 3 | bangkalan
# Processing Record 34 of Set 3 | sosnovo
# Processing Record 35 of Set 3 | kourou
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | penzance
# Processing Record 38 of Set 3 | galle
# Processing Record 39 of Set 3 | yellowknife
# Processing Record 40 of Set 3 | bonavista
# Processing Record 41 of Set 3 | burica
# City not found. Skipping...
# Processing Record 42 of Set 3 | non sang
# Processing Record 43 of Set 3 | axim
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | wawa
# Processing Record 46 of Set 3 | itarema
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | gazojak
# Processing Record 49 of Set 3 | dien bien
# City not found. Skipping...
# Processing Record 0 of Set 4 | kyzyl-mazhalyk
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | itoman
# Processing Record 3 of Set 4 | tambura
# Processing Record 4 of Set 4 | omboue
# Processing Record 5 of Set 4 | charlestown
# Processing Record 6 of Set 4 | wellington
# Processing Record 7 of Set 4 | asau
# Processing Record 8 of Set 4 | henties bay
# Processing Record 9 of Set 4 | constitucion
# Processing Record 10 of Set 4 | san patricio
# Processing Record 11 of Set 4 | nizwa
# Processing Record 12 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 4 | sao joao da barra
# Processing Record 14 of Set 4 | chor
# Processing Record 15 of Set 4 | barrow
# Processing Record 16 of Set 4 | tyrma
# Processing Record 17 of Set 4 | murgab
# Processing Record 18 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 4 | clyde river
# Processing Record 20 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 21 of Set 4 | zhigansk
# Processing Record 22 of Set 4 | cap malheureux
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | maniitsoq
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | la ronge
# Processing Record 27 of Set 4 | sale
# Processing Record 28 of Set 4 | nuuk
# Processing Record 29 of Set 4 | calbe
# Processing Record 30 of Set 4 | zhangye
# Processing Record 31 of Set 4 | bethel
# Processing Record 32 of Set 4 | west wendover
# Processing Record 33 of Set 4 | maumere
# Processing Record 34 of Set 4 | buta
# Processing Record 35 of Set 4 | tual
# Processing Record 36 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 4 | bambous virieux
# Processing Record 38 of Set 4 | tuktoyaktuk
# Processing Record 39 of Set 4 | bosaso
# Processing Record 40 of Set 4 | mecca
# Processing Record 41 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 42 of Set 4 | colesberg
# Processing Record 43 of Set 4 | meulaboh
# Processing Record 44 of Set 4 | dharchula
# Processing Record 45 of Set 4 | neiafu
# Processing Record 46 of Set 4 | mizdah
# Processing Record 47 of Set 4 | lyuban
# Processing Record 48 of Set 4 | souillac
# Processing Record 49 of Set 4 | sigerfjord
# City not found. Skipping...
# Processing Record 0 of Set 5 | chauk
# Processing Record 1 of Set 5 | bowen
# Processing Record 2 of Set 5 | port blair
# Processing Record 3 of Set 5 | san luis
# Processing Record 4 of Set 5 | talnakh
# Processing Record 5 of Set 5 | kolaras
# Processing Record 6 of Set 5 | klyuchi
# Processing Record 7 of Set 5 | magistralnyy
# Processing Record 8 of Set 5 | ambilobe
# Processing Record 9 of Set 5 | maningrida
# Processing Record 10 of Set 5 | auki
# Processing Record 11 of Set 5 | inhambane
# Processing Record 12 of Set 5 | finote selam
# Processing Record 13 of Set 5 | namibe
# Processing Record 14 of Set 5 | tautira
# Processing Record 15 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 5 | podstepki
# Processing Record 17 of Set 5 | padang
# Processing Record 18 of Set 5 | cape town
# Processing Record 19 of Set 5 | kalmunai
# Processing Record 20 of Set 5 | harper
# Processing Record 21 of Set 5 | san carlos de bariloche
# Processing Record 22 of Set 5 | tazovskiy
# Processing Record 23 of Set 5 | bealanana
# Processing Record 24 of Set 5 | susangerd
# Processing Record 25 of Set 5 | vadso
# Processing Record 26 of Set 5 | coelho neto
# Processing Record 27 of Set 5 | katsuura
# Processing Record 28 of Set 5 | longyearbyen
# Processing Record 29 of Set 5 | sitka
# Processing Record 30 of Set 5 | los llanos de aridane
# Processing Record 31 of Set 5 | sistranda
# Processing Record 32 of Set 5 | svetlogorsk
# Processing Record 33 of Set 5 | khash
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | mar del plata
# Processing Record 36 of Set 5 | praya
# Processing Record 37 of Set 5 | east london
# Processing Record 38 of Set 5 | qesarya
# Processing Record 39 of Set 5 | rio grande
# Processing Record 40 of Set 5 | qaanaaq
# Processing Record 41 of Set 5 | caravelas
# Processing Record 42 of Set 5 | namatanai
# Processing Record 43 of Set 5 | grao mogol
# Processing Record 44 of Set 5 | burnie
# Processing Record 45 of Set 5 | guanica
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | tortoli
# Processing Record 48 of Set 5 | pangody
# Processing Record 49 of Set 5 | avera
# Processing Record 0 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 6 | upernavik
# Processing Record 2 of Set 6 | les cayes
# Processing Record 3 of Set 6 | paveh
# Processing Record 4 of Set 6 | mailsi
# Processing Record 5 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | buala
# Processing Record 8 of Set 6 | krasnoselkup
# Processing Record 9 of Set 6 | touros
# Processing Record 10 of Set 6 | vallenar
# Processing Record 11 of Set 6 | aswan
# Processing Record 12 of Set 6 | saint george
# Processing Record 13 of Set 6 | jalu
# Processing Record 14 of Set 6 | maua
# Processing Record 15 of Set 6 | pouebo
# Processing Record 16 of Set 6 | chengde
# Processing Record 17 of Set 6 | leningradskiy
# Processing Record 18 of Set 6 | solikamsk
# Processing Record 19 of Set 6 | sola
# Processing Record 20 of Set 6 | darnah
# Processing Record 21 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | halifax
# Processing Record 24 of Set 6 | whitianga
# Processing Record 25 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 26 of Set 6 | chadan
# Processing Record 27 of Set 6 | lafia
# Processing Record 28 of Set 6 | sarkand
# Processing Record 29 of Set 6 | ambon
# Processing Record 30 of Set 6 | lompoc
# Processing Record 31 of Set 6 | worland
# Processing Record 32 of Set 6 | gisborne
# Processing Record 33 of Set 6 | rocha
# Processing Record 34 of Set 6 | kruisfontein
# Processing Record 35 of Set 6 | tamalameque
# Processing Record 36 of Set 6 | ekhabi
# Processing Record 37 of Set 6 | vuktyl
# Processing Record 38 of Set 6 | kosice
# Processing Record 39 of Set 6 | bitam
# Processing Record 40 of Set 6 | cherskiy
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | yadrin
# Processing Record 43 of Set 6 | lakes entrance
# Processing Record 44 of Set 6 | carutapera
# Processing Record 45 of Set 6 | bandarbeyla
# Processing Record 46 of Set 6 | mountrath
# Processing Record 47 of Set 6 | kavieng
# Processing Record 48 of Set 6 | colwyn bay
# Processing Record 49 of Set 6 | sao lourenco do sul
# Processing Record 0 of Set 7 | holme
# Processing Record 1 of Set 7 | ahuimanu
# Processing Record 2 of Set 7 | porbandar
# Processing Record 3 of Set 7 | singaraja
# Processing Record 4 of Set 7 | ahipara
# Processing Record 5 of Set 7 | dwarka
# Processing Record 6 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 7 | college
# Processing Record 8 of Set 7 | sibolga
# Processing Record 9 of Set 7 | urumqi
# Processing Record 10 of Set 7 | neuquen
# Processing Record 11 of Set 7 | pontes e lacerda
# Processing Record 12 of Set 7 | nisia floresta
# Processing Record 13 of Set 7 | kamenka
# Processing Record 14 of Set 7 | belawan
# Processing Record 15 of Set 7 | tessalit
# Processing Record 16 of Set 7 | port macquarie
# Processing Record 17 of Set 7 | panaba
# Processing Record 18 of Set 7 | osoyoos
# Processing Record 19 of Set 7 | saldanha
# Processing Record 20 of Set 7 | methven
# Processing Record 21 of Set 7 | airai
# Processing Record 22 of Set 7 | puerto carreno
# Processing Record 23 of Set 7 | yarovoye
# Processing Record 24 of Set 7 | gayeri
# Processing Record 25 of Set 7 | beringovskiy
# Processing Record 26 of Set 7 | luderitz
# Processing Record 27 of Set 7 | anju
# Processing Record 28 of Set 7 | lithakia
# Processing Record 29 of Set 7 | aksu
# Processing Record 30 of Set 7 | teya
# Processing Record 31 of Set 7 | werda
# Processing Record 32 of Set 7 | coquimbo
# Processing Record 33 of Set 7 | mayo
# Processing Record 34 of Set 7 | pakxan
# Processing Record 35 of Set 7 | dali
# Processing Record 36 of Set 7 | yabrud
# Processing Record 37 of Set 7 | matara
# Processing Record 38 of Set 7 | soe
# Processing Record 39 of Set 7 | victoria
# Processing Record 40 of Set 7 | pevek
# Processing Record 41 of Set 7 | ratnagiri
# Processing Record 42 of Set 7 | sisimiut
# Processing Record 43 of Set 7 | vestmanna
# Processing Record 44 of Set 7 | severo-yeniseyskiy
# Processing Record 45 of Set 7 | quatre cocos
# Processing Record 46 of Set 7 | waipawa
# Processing Record 47 of Set 7 | vastervik
# City not found. Skipping...
# Processing Record 48 of Set 7 | maceio
# Processing Record 49 of Set 7 | turayf
# Processing Record 0 of Set 8 | sidhi
# Processing Record 1 of Set 8 | quang ngai
# Processing Record 2 of Set 8 | yerbogachen
# Processing Record 3 of Set 8 | shizuishan
# Processing Record 4 of Set 8 | redmond
# Processing Record 5 of Set 8 | seoul
# Processing Record 6 of Set 8 | severo-kurilsk
# Processing Record 7 of Set 8 | saint-ambroise
# Processing Record 8 of Set 8 | saint-philippe
# Processing Record 9 of Set 8 | kavaratti
# Processing Record 10 of Set 8 | makakilo city
# Processing Record 11 of Set 8 | roald
# Processing Record 12 of Set 8 | maymanak
# City not found. Skipping...
# Processing Record 13 of Set 8 | emerald
# Processing Record 14 of Set 8 | kodiak
# Processing Record 15 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 8 | lebedinyy
# Processing Record 17 of Set 8 | brainerd
# Processing Record 18 of Set 8 | nakamura
# Processing Record 19 of Set 8 | ribeirao das neves
# Processing Record 20 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 8 | mandan
# Processing Record 22 of Set 8 | isangel
# Processing Record 23 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 24 of Set 8 | bitung
# Processing Record 25 of Set 8 | jumla
# Processing Record 26 of Set 8 | orocue
# Processing Record 27 of Set 8 | puerto cortes
# City not found. Skipping...
# Processing Record 28 of Set 8 | fortuna
# Processing Record 29 of Set 8 | tillabery
# City not found. Skipping...
# Processing Record 30 of Set 8 | stephenville crossing
# Processing Record 31 of Set 8 | braganca
# Processing Record 32 of Set 8 | kraskino
# Processing Record 33 of Set 8 | fort nelson
# Processing Record 34 of Set 8 | marrakesh
# Processing Record 35 of Set 8 | pangnirtung
# Processing Record 36 of Set 8 | aljezur
# Processing Record 37 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 8 | bilma
# Processing Record 39 of Set 8 | broome
# Processing Record 40 of Set 8 | turukhansk
# Processing Record 41 of Set 8 | codrington
# Processing Record 42 of Set 8 | moron
# Processing Record 43 of Set 8 | eureka
# Processing Record 44 of Set 8 | bolshiye uki
# City not found. Skipping...
# Processing Record 45 of Set 8 | bonthe
# Processing Record 46 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 47 of Set 8 | maues
# Processing Record 48 of Set 8 | hirado
# Processing Record 49 of Set 8 | shimoda
# Processing Record 0 of Set 9 | baykit
# Processing Record 1 of Set 9 | havoysund
# Processing Record 2 of Set 9 | el carmen
# Processing Record 3 of Set 9 | port hawkesbury
# Processing Record 4 of Set 9 | makinsk
# Processing Record 5 of Set 9 | tilichiki
# Processing Record 6 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 9 | razole
# Processing Record 8 of Set 9 | kyren
# Processing Record 9 of Set 9 | santa maria
# Processing Record 10 of Set 9 | linxia
# Processing Record 11 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 9 | port said
# Processing Record 13 of Set 9 | kysyl-syr
# Processing Record 14 of Set 9 | shaami-yurt
# Processing Record 15 of Set 9 | anadyr
# Processing Record 16 of Set 9 | shingu
# Processing Record 17 of Set 9 | aykhal
# Processing Record 18 of Set 9 | yarada
# Processing Record 19 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 9 | caluquembe
# Processing Record 21 of Set 9 | havelock
# Processing Record 22 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 9 | sonoita
# Processing Record 24 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 25 of Set 9 | sao raimundo nonato
# Processing Record 26 of Set 9 | kajaani
# Processing Record 27 of Set 9 | lavrentiya
# Processing Record 28 of Set 9 | korsakovo
# Processing Record 29 of Set 9 | mataram
# Processing Record 30 of Set 9 | calabozo
# Processing Record 31 of Set 9 | namuac
# Processing Record 32 of Set 9 | marystown
# Processing Record 33 of Set 9 | dembi dolo
# Processing Record 34 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 9 | richards bay
# Processing Record 36 of Set 9 | skibbereen
# Processing Record 37 of Set 9 | kutum
# Processing Record 38 of Set 9 | necochea
# Processing Record 39 of Set 9 | dunedin
# Processing Record 40 of Set 9 | perehonivka
# Processing Record 41 of Set 9 | ancud
# Processing Record 42 of Set 9 | ganzhou
# Processing Record 43 of Set 9 | fairview
# Processing Record 44 of Set 9 | sioux lookout
# Processing Record 45 of Set 9 | benguela
# Processing Record 46 of Set 9 | egvekinot
# Processing Record 47 of Set 9 | ilulissat
# Processing Record 48 of Set 9 | walla walla
# Processing Record 49 of Set 9 | pamanukan
# Processing Record 0 of Set 10 | taltal
# Processing Record 1 of Set 10 | sur
# Processing Record 2 of Set 10 | samarai
# Processing Record 3 of Set 10 | aksarka
# Processing Record 4 of Set 10 | kijang
# Processing Record 5 of Set 10 | duz
# City not found. Skipping...
# Processing Record 6 of Set 10 | amahai
# Processing Record 7 of Set 10 | hovd
# Processing Record 8 of Set 10 | dickinson
# Processing Record 9 of Set 10 | asheville
# Processing Record 10 of Set 10 | tigil
# Processing Record 11 of Set 10 | viransehir
# Processing Record 12 of Set 10 | luwuk
# Processing Record 13 of Set 10 | vestmannaeyjar
# Processing Record 14 of Set 10 | mount isa
# Processing Record 15 of Set 10 | sorong
# Processing Record 16 of Set 10 | juegang
# Processing Record 17 of Set 10 | kodinsk
# Processing Record 18 of Set 10 | idlib
# Processing Record 19 of Set 10 | dire
# Processing Record 20 of Set 10 | vila velha
# Processing Record 21 of Set 10 | karratha
# Processing Record 22 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 10 | santiago del estero
# Processing Record 24 of Set 10 | vincennes
# Processing Record 25 of Set 10 | awka
# Processing Record 26 of Set 10 | akdepe
# Processing Record 27 of Set 10 | cockburn town
# Processing Record 28 of Set 10 | hualmay
# Processing Record 29 of Set 10 | alofi
# Processing Record 30 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 10 | marang
# Processing Record 32 of Set 10 | pervomayskiy
# Processing Record 33 of Set 10 | manzhouli
# Processing Record 34 of Set 10 | marsabit
# Processing Record 35 of Set 10 | mendeleyevo
# Processing Record 36 of Set 10 | zhangjiakou
# Processing Record 37 of Set 10 | agadir
# Processing Record 38 of Set 10 | mastic beach
# Processing Record 39 of Set 10 | przasnysz
# Processing Record 40 of Set 10 | nhulunbuy
# Processing Record 41 of Set 10 | pochutla
# Processing Record 42 of Set 10 | bubaque
# Processing Record 43 of Set 10 | newport
# Processing Record 44 of Set 10 | kasongo-lunda
# Processing Record 45 of Set 10 | gigmoto
# Processing Record 46 of Set 10 | sorland
# Processing Record 47 of Set 10 | tongliao
# Processing Record 48 of Set 10 | revda
# Processing Record 49 of Set 10 | naifaru
# Processing Record 0 of Set 11 | gizo
# Processing Record 1 of Set 11 | le port
# Processing Record 2 of Set 11 | dudinka
# Processing Record 3 of Set 11 | plymouth
# Processing Record 4 of Set 11 | benjamin constant
# Processing Record 5 of Set 11 | hami
# Processing Record 6 of Set 11 | saint anthony
# Processing Record 7 of Set 11 | port lincoln
# Processing Record 8 of Set 11 | chuy
# Processing Record 9 of Set 11 | ascension
# Processing Record 10 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 11 | maarianhamina
# Processing Record 12 of Set 11 | grindavik
# Processing Record 13 of Set 11 | ulety
# Processing Record 14 of Set 11 | kununurra
# Processing Record 15 of Set 11 | broken hill
# Processing Record 16 of Set 11 | sydney
# Processing Record 17 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 11 | aksay
# Processing Record 19 of Set 11 | pafos
# Processing Record 20 of Set 11 | solnechnyy
# Processing Record 21 of Set 11 | aklavik
# Processing Record 22 of Set 11 | keetmanshoop
# Processing Record 23 of Set 11 | gunnedah
# Processing Record 24 of Set 11 | duiwelskloof
# Processing Record 25 of Set 11 | palomares
# Processing Record 26 of Set 11 | de-kastri
# Processing Record 27 of Set 11 | awjilah
# Processing Record 28 of Set 11 | chipinge
# Processing Record 29 of Set 11 | farafangana
# Processing Record 30 of Set 11 | weihai
# Processing Record 31 of Set 11 | port hardy
# Processing Record 32 of Set 11 | matay
# Processing Record 33 of Set 11 | wuwei
# Processing Record 34 of Set 11 | namie
# Processing Record 35 of Set 11 | chabahar
# Processing Record 36 of Set 11 | donskoye
# Processing Record 37 of Set 11 | thatcham
# Processing Record 38 of Set 11 | harbour breton
# Processing Record 39 of Set 11 | imbituba
# Processing Record 40 of Set 11 | bo rai
# Processing Record 41 of Set 11 | iqaluit
# Processing Record 42 of Set 11 | ketchikan
# Processing Record 43 of Set 11 | dabakala
# Processing Record 44 of Set 11 | acajutla
# Processing Record 45 of Set 11 | rock sound
# Processing Record 46 of Set 11 | kloulklubed
# Processing Record 47 of Set 11 | upata
# Processing Record 48 of Set 11 | ballina
# Processing Record 49 of Set 11 | mamurras
# Processing Record 0 of Set 12 | champerico
# Processing Record 1 of Set 12 | kosh-agach
# Processing Record 2 of Set 12 | dong hoi
# Processing Record 3 of Set 12 | manavalakurichi
# Processing Record 4 of Set 12 | hervey bay
# Processing Record 5 of Set 12 | tukrah
# Processing Record 6 of Set 12 | keffi
# Processing Record 7 of Set 12 | chara
# Processing Record 8 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 9 of Set 12 | vostok
# Processing Record 10 of Set 12 | bud
# Processing Record 11 of Set 12 | tommot
# Processing Record 12 of Set 12 | weyburn
# Processing Record 13 of Set 12 | sebinkarahisar
# Processing Record 14 of Set 12 | viesite
# Processing Record 15 of Set 12 | verkhnyaya inta
# Processing Record 16 of Set 12 | kano
# Processing Record 17 of Set 12 | suicheng
# Processing Record 18 of Set 12 | marzuq
# Processing Record 19 of Set 12 | susanville
# Processing Record 20 of Set 12 | asfi
# Processing Record 21 of Set 12 | nalut
# Processing Record 22 of Set 12 | yar-sale
# Processing Record 23 of Set 12 | tartus
# Processing Record 24 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 12 | gerede
# Processing Record 26 of Set 12 | bullhead city
# Processing Record 27 of Set 12 | smithers
# Processing Record 28 of Set 12 | ngunguru
# Processing Record 29 of Set 12 | banda aceh
# Processing Record 30 of Set 12 | villa oliva
# City not found. Skipping...
# Processing Record 31 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 12 | camacha
# Processing Record 33 of Set 12 | faya
# Processing Record 34 of Set 12 | bandar-e anzali
# Processing Record 35 of Set 12 | yanam
# Processing Record 36 of Set 12 | kamina
# Processing Record 37 of Set 12 | fairbanks
# Processing Record 38 of Set 12 | bundibugyo
# Processing Record 39 of Set 12 | derzhavinsk
# Processing Record 40 of Set 12 | council bluffs
# Processing Record 41 of Set 12 | sept-iles
# Processing Record 42 of Set 12 | tallahassee
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_data)
city_df.head()
# Out:
#             City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      nantucket  41.2835 -70.0995     24.80        68           1
# 1            leh  34.1667  77.5833     -0.56        64          53
# 2         waddan  29.1614  16.1390     57.92        37          96
# 3  benito juarez  19.3850 -99.1650     66.20        42          75
# 4          nioro  13.3500 -15.7500     67.19        26           0
#
#    Wind Speed Country        Date
# 0        3.44      US  1611624863
# 1        1.21      IN  1611624782
# 2        4.65      LY  1611625030
# 3       14.97      MX  1611625030
# 4        0.51      GM  1611624938

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  540.000000  540.000000  540.000000  540.000000  540.000000  540.000000
# mean    20.385350   23.588586   48.118944   74.840741   56.801852    7.977241
# std     33.597212   90.514252   33.215459   18.892151   39.815106    5.853990
# min    -54.800000 -179.166700  -56.110000   19.000000    0.000000    0.070000
# 25%     -7.309875  -53.706850   30.035000   64.750000   19.750000    3.440000
# 50%     27.015050   29.741000   57.990000   79.500000   75.000000    6.910000
# 75%     48.712525  102.324125   75.000000   88.000000   99.000000   10.360000
# max     78.218600  179.316700  100.400000  100.000000  100.000000   36.600000
#
#                Date
# count  5.400000e+02
# mean   1.611625e+09
# std    8.815641e+01
# min    1.611625e+09
# 25%    1.611625e+09
# 50%    1.611625e+09
# 75%    1.611625e+09
# max    1.611625e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humid_df = city_df[city_df["Humidity"] > 100].index
humid_df
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_df.drop(humid_df, inplace=False)
clean_city_data.head()
# Out:
#             City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      nantucket  41.2835 -70.0995     24.80        68           1
# 1            leh  34.1667  77.5833     -0.56        64          53
# 2         waddan  29.1614  16.1390     57.92        37          96
# 3  benito juarez  19.3850 -99.1650     66.20        42          75
# 4          nioro  13.3500 -15.7500     67.19        26           0
#
#    Wind Speed Country        Date
# 0        3.44      US  1611624863
# 1        1.21      IN  1611624782
# 2        4.65      LY  1611625030
# 3       14.97      MX  1611625030
# 4        0.51      GM  1611624938

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#x = clean_city_data["Lat"]
#y = clean_city_data["Max Temp"]

plt.scatter(clean_city_data["Lat"],clean_city_data["Max Temp"])#, markeredgecolor=k, markeredgewidth="0.5")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Temperature (%s)" % time.strftime("%x"))
plt.grid(True)
#plt.savefig("output_data/lat_vs_temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Humidity"])#, markeredgecolor=k, markeredgewidth="0.5")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.grid(True)
#plt.savefig("output_data/lat_vs_temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Cloudiness"])#, markeredgecolor=k, markeredgewidth="0.5")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.grid(True)
#plt.savefig("output_data/lat_vs_temp.png")
plt.show()

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Cloudiness"])#, markeredgecolor=k, markeredgewidth="0.5")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.grid(True)
#plt.savefig("output_data/lat_vs_temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Wind Speed"])#, markeredgecolor=k, markeredgewidth="0.5")
plt.ylabel("Wind Speed (%)")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.grid(True)
#plt.savefig("output_data/lat_vs_temp.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
